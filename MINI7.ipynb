# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, Lasso, Ridge

rng = np.random.RandomState(1)
x = 10 * rng.rand(50)
y = 2 * x - 5 + rng.randn(50)

model = LinearRegression()
model.fit(x.reshape(-1,1),y)
y_pred = model.predict(x.reshape(-1,1))

plt.scatter(x,y)
plt.plot(x,y_pred,color='red')
plt.title('Linear Regression')
plt.xlabel('x')
plt.ylabel('y')
plt.show

#print the coefficient and intercept

print('Coefficints:',model.coef_)
print('Intercept:',model.intercept_)
# Out:
# Coefficints: [2.02720881]
# Intercept: -4.9985770855532

# %%
model_lasso = Lasso(alpha=0.1)
model_lasso.fit(x.reshape(-1,1),y)
y_pred_lasso = model_lasso.predict(x.reshape(-1,1))

model_ridge = Ridge(alpha=0.1)
model_ridge.fit(x.reshape(-1,1),y)
y_pred_lasso = model_lasso_predict(x.reshape(-1,1))

plt.scatter(x,y)
plt.plot(x, y_pred, color='red',label='Linear Regression')
plt.plot(x, y_pred_lasso, color='green', label='Lasso Regression')
plt.plot(x, y_pred_ridge, color = 'orange', label = 'Ridge Regression')
plttitle('Linear Regression vs Lasso vs Ridge')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

#print the coefficients and intercept

print('Linear Regression Coefficients:', model.coef_)
print('Linear Regression Intercept:',model.intercept_)

print('Lasso Regression Coefficients:', model.coef_)
print('Lasso Regression Intercept:', model.intercept_)

print('Ridge Regression Coefficients:', model.coef_)
print('Ridge Regression:', model.intercept_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 7
#       5 model_ridge = Ridge(alpha=0.1)
#       6 model_ridge.fit(x.reshape(-1,1),y)
# ----> 7 y_pred_lasso = model_lasso_predict(x.reshape(-1,1))
#       9 plt.scatter(x,y)
#      10 plt.plot(x, y_pred, color='red',label='Linear Regression')
#
# NameError: name 'model_lasso_predict' is not defined
